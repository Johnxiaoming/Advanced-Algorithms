# %%
import sys

file = open("/content/drive/MyDrive/Colab Notebooks/Rosalind/rosalind_ba7a.txt")

# %%
def adj_get(i, j):
  if adj_mat[i][j] != adj_mat[j][i]:
    print("Error! Matrix not mirrored")
    return
  return adj_mat[i][j]

# %%
def adj_set(i, j, v):
  adj_mat[i][j] = v
  adj_mat[j][i] = v

data = file.readlines()
num_leaves = int(data[0])
num_nodes = int(data[-1][:data[-1].find("->")]) + 1
adj_mat = [[0 for i in range(num_nodes)] for i in range(num_nodes)]

for line in data[1:]:
  mark1 = line.find("->")
  mark2 = line.find(":")
  start = int(line[:mark1])
  end = int(line[mark1 + 2:mark2])
  weight = int(line[mark2 + 1:])
  adj_mat[start][end] = weight

for i in range(num_nodes):
  for j in range(i, num_nodes):
    limb = adj_get(i, j)
    if limb == 0: #test the comments
      continue
    else:
      for x in range(num_nodes):
        other_limb = adj_get(x, j)
        if x == i or other_limb == 0:
          continue
        elif adj_get(i, x) == 0:
          adj_set(i, x, other_limb + limb)

# %%
for i in adj_mat[:num_leaves]:
  for j in i[:num_leaves]:
    print(j, end = " ")
  print()
# Out:
# 0 140 217 67 203 162 195 70 34 79 229 61 127 38 60 60 33 249 83 247 158 229 43 73 81 240 101 153 131 177 47 110
# 140 0 93 97 79 38 71 84 158 71 105 185 35 162 104 184 127 125 85 123 34 105 167 197 205 116 65 29 23 53 115 44
# 217 93 0 174 28 73 50 161 235 148 34 262 112 239 181 261 204 54 162 52 79 34 244 274 282 45 142 92 100 62 192 121
# 67 97 174 0 160 119 152 27 85 36 186 112 84 89 31 111 54 206 40 204 115 186 94 124 132 197 58 110 88 134 42 67
# 203 79 28 160 0 59 36 147 221 134 40 248 98 225 167 247 190 60 148 58 65 40 230 260 268 51 128 78 86 48 178 107
# 162 38 73 119 59 0 51 106 180 93 85 207 57 184 126 206 149 105 107 103 24 85 189 219 227 96 87 37 45 33 137 66
# 195 71 50 152 36 51 0 139 213 126 62 240 90 217 159 239 182 82 140 80 57 62 222 252 260 73 120 70 78 40 170 99
# 70 84 161 27 147 106 139 0 88 23 173 115 71 92 34 114 57 193 27 191 102 173 97 127 135 184 45 97 75 121 45 54
# 34 158 235 85 221 180 213 88 0 97 247 51 145 28 78 50 51 267 101 265 176 247 33 63 71 258 119 171 149 195 65 128
# 79 71 148 36 134 93 126 23 97 0 160 124 58 101 43 123 66 180 24 178 89 160 106 136 144 171 32 84 62 108 54 41
# 229 105 34 186 40 85 62 173 247 160 0 274 124 251 193 273 216 32 174 30 91 28 256 286 294 23 154 104 112 74 204 133
# 61 185 262 112 248 207 240 115 51 124 274 0 172 39 105 27 78 294 128 292 203 274 30 22 30 285 146 198 176 222 92 155
